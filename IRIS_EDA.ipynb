# %% [markdown]
# <a href="https://colab.research.google.com/github/lizathulya/Data_Analytics_/blob/main/IRIS_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# About this Dataset:IRIS CSV
# Context
# The Iris flower data set is a multivariate data set introduced by the British statistician and biologist Ronald Fisher in his 1936 paper The use of multiple measurements in taxonomic problems. It is sometimes called Anderson's Iris data set because Edgar Anderson collected the data to quantify the morphologic variation of Iris flowers of three related species. The data set consists of 50 samples from each of three species of Iris (Iris Setosa, Iris virginica, and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# This dataset became a typical test case for many statistical classification techniques in machine learning such as support vector machines
#
# Content
# The dataset contains a set of 150 records under 5 attributes - Petal Length, Petal Width, Sepal Length, Sepal width and Class(Species).
#
# Acknowledgements
# This dataset is free and is publicly available at the UCI Machine Learning Repository

# %%
import numpy as np#
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
iris = pd.read_csv(r'/content/IRIS.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Checking the number of rows and columns
#Data
num_train_rows, num_train_columns = iris.shape
#Printing the number of rows and columns.
print("Iris Flower Data:")
print(f"Number of Rows: {num_train_rows}")
print(f"Number of Columns: {num_train_columns}\n")
# Out:
# Iris Flower Data:
# Number of Rows: 150
# Number of Columns: 5

# %%
iris.columns #gives the names of columns in the dataset
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
Species = iris['species'].value_counts().reset_index() # no of flowers in each quantites
Species
# Out:
#            species  count
# 0      Iris-setosa     50
# 1  Iris-versicolor     50
# 2   Iris-virginica     50

# %% [markdown]
# We can observe that the data is balanced data

# %%
# Null Values in Train
iris_null = iris.isnull().sum().sum()

print(f'Null Count in Data: {iris_null}')
# Out:
# Null Count in Data: 0

# %%
#2d plot with color coding for each flower type/class
sns.set_style('whitegrid');
#hue='species' color codes each variety
sns.FacetGrid(iris,hue='species',height=5)\
        .map(plt.scatter,'sepal_length','sepal_width')\
         .add_legend()
plt.show()

# %% [markdown]
# We can observe that the blue color helps to distinguish setosa from others and we cannot seprate the reest as they have condiderable overlap

# %%
#Pair-plot for better visualization
sns.pairplot(iris,hue='species',height=3)
plt.show()

# %%
# 1 D plot using just one feature(sepal_length)
iris_setosa = iris[iris['species']=='Iris-setosa']
iris_virginica = iris[iris['species']=='Iris-virginica']
iris_versicolor = iris[iris['species']=='Iris-versicolor']

plt.plot(iris_setosa['sepal_length'],np.zeros_like(iris_setosa['sepal_length']))
plt.plot(iris_virginica['sepal_length'],np.zeros_like(iris_virginica['sepal_length']))
plt.plot(iris_versicolor['sepal_length'],np.zeros_like(iris_versicolor['sepal_length']))
plt.legend(['Iris-setosa','Iris-virginica','Iris-versicolor'])

# %%
# distribution plot of petal length of all flowers
sns.FacetGrid(iris,hue='species',height=5)\
        .map(sns.distplot,'petal_length')\
         .add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
# distribution plot of petal length of all flowers
sns.FacetGrid(iris,hue='species',height=5)\
        .map(sns.distplot,'sepal_length')\
         .add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
# distribution plot of petal length of all flowers
sns.FacetGrid(iris,hue='species',height=5)\
        .map(sns.distplot,'sepal_width')\
         .add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %% [markdown]
# **Observations**
#
# *   petal_length is performing well on seprating class
# *   we should select petal_length
#
# *overall:PL>PW>>SL>>SW*

# %%
#plotting cdf oof petal length

counts,bin_edges = np.histogram(iris['petal_length'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)
cdf = np.cumsum(pdf)
plt.xlabel('petal_length')
plt.ylabel('probability')
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# [0.24666667 0.08666667 0.         0.02       0.05333333 0.17333333
#  0.19333333 0.12       0.07333333 0.03333333]
# [1.   1.59 2.18 2.77 3.36 3.95 4.54 5.13 5.72 6.31 6.9 ]

# %% [markdown]
# Blue is PDF and Orange is CDF

# %%
#plotting CDF for various species
#setosa
counts,bin_edges = np.histogram(iris_setosa['petal_length'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)
cdf = np.cumsum(pdf)
plt.xlabel('petal_length')
plt.ylabel('probability')
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
#versicolor
counts,bin_edges = np.histogram(iris_versicolor['petal_length'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)
cdf = np.cumsum(pdf)
plt.xlabel('petal_length')
plt.ylabel('probability')
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
#virginica
counts,bin_edges = np.histogram(iris_virginica['petal_length'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)
cdf = np.cumsum(pdf)
plt.xlabel('petal_length')
plt.ylabel('probability')
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]
# [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]

# %%
# mean varience and std deviation for each species
print('Iris-setosa')
print('Mean :',iris_setosa['petal_length'].mean())
print('Varience :',iris_setosa['petal_length'].var())
print('Standard_dev :',iris_setosa['petal_length'].std())

print('Iris-versicolor')
print('Mean :',iris_versicolor['petal_length'].mean())
print('Varience :',iris_versicolor['petal_length'].var())
print('Standard_dev :',iris_versicolor['petal_length'].std())

print('Iris-virginica')
print('Mean :',iris_virginica['petal_length'].mean())
print('Varience :',iris_virginica['petal_length'].var())
print('Standard_dev :',iris_virginica['petal_length'].std())
# Out:
# Iris-setosa
# Mean : 1.464
# Varience : 0.030106122448979603
# Standard_dev : 0.1735111594364455
# Iris-versicolor
# Mean : 4.26
# Varience : 0.22081632653061237
# Standard_dev : 0.46991097723995806
# Iris-virginica
# Mean : 5.5520000000000005
# Varience : 0.304587755102041
# Standard_dev : 0.5518946956639835

# %%
# Create a box plot to show the relationship between a numerical variable and a categorical variable
custom_colors = ['green', 'blue', 'orange']
fig_boxplot = sns.boxplot(iris, x="species", y="sepal_length",
                     hue='species',  # Change 'color' to 'hue' to color by species
                     palette=custom_colors  # Use 'palette' to specify custom colors
                    )

# %%
sns.violinplot(x='species',y='petal_length',data=iris)
plt.show()

# %%
sns.jointplot(x='petal_length',y='petal_width',data=iris,kind='kde')
plt.show()

# %%
numeric_features = [col for col in iris.columns if iris[col].dtype in ['int64', 'float64']]

# Calculate the number of rows and columns for subplots
num_features = len(numeric_features)
num_rows = math.ceil(num_features / 4)  # Adjust the number 4 based on how many plots you want per row
num_cols = min(num_features, 4)

# Set up the figure and axes for subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(5*num_cols, 5*num_rows))

# Flatten the axes for easier iteration
axes = axes.flatten()

sns.set_theme(style="darkgrid")

# Loop through each numerical feature and create a distribution plot with custom bar color
for i, col in enumerate(numeric_features):
    sns.histplot(iris[col], kde=True, ax=axes[i])
    axes[i].set_title(col)
    axes[i].set_facecolor('skyblue')  # Set background color to skyblue
# Remove any unused subplots
for i in range(num_features, num_rows*num_cols):
    fig.delaxes(axes[i])

# Adjust layout
plt.tight_layout()
plt.show()
